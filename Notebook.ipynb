# %%
# !python3 -m pip install confluence-markdown-exporter
# Out:
# Requirement already satisfied: confluence-markdown-exporter in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.1.0)
# Requirement already satisfied: atlassian-python-api in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (4.0.7)
# Requirement already satisfied: jmespath in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (1.0.1)
# Requirement already satisfied: lxml>=6.0.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (6.0.2)
# Requirement already satisfied: markdownify in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (1.2.2)
# Requirement already satisfied: pydantic-settings in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (2.12.0)
# Requirement already satisfied: python-dateutil in /Users/janishuser/Library/Python/3.12/lib/python/site-packages (from confluence-markdown-exporter) (2.9.0.post0)
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (6.0.3)
# Requirement already satisfied: questionary in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (2.1.1)
# Requirement already satisfied: tabulate in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (0.9.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (4.67.1)
# Requirement already satisfied: typer in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from confluence-markdown-exporter) (0.20.0)
# Requirement already satisfied: deprecated in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from atlassian-python-api->confluence-markdown-exporter) (1.3.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from atlassian-python-api->confluence-markdown-exporter) (2.32.3)
# Requirement already satisfied: oauthlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from atlassian-python-api->confluence-markdown-exporter) (3.3.1)
# Requirement already satisfied: requests_oauthlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from atlassian-python-api->confluence-markdown-exporter) (2.0.0)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from atlassian-python-api->confluence-markdown-exporter) (4.13.4)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from atlassian-python-api->confluence-markdown-exporter) (4.15.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4->atlassian-python-api->confluence-markdown-exporter) (2.7)
# Requirement already satisfied: wrapt<3,>=1.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from deprecated->atlassian-python-api->confluence-markdown-exporter) (1.17.2)
# Requirement already satisfied: six<2,>=1.15 in /Users/janishuser/Library/Python/3.12/lib/python/site-packages (from markdownify->confluence-markdown-exporter) (1.17.0)
# Requirement already satisfied: pydantic>=2.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic-settings->confluence-markdown-exporter) (2.12.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic-settings->confluence-markdown-exporter) (1.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic-settings->confluence-markdown-exporter) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic>=2.7.0->pydantic-settings->confluence-markdown-exporter) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic>=2.7.0->pydantic-settings->confluence-markdown-exporter) (2.41.5)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /Users/janishuser/Library/Python/3.12/lib/python/site-packages (from questionary->confluence-markdown-exporter) (3.0.51)
# Requirement already satisfied: wcwidth in /Users/janishuser/Library/Python/3.12/lib/python/site-packages (from prompt_toolkit<4.0,>=2.0->questionary->confluence-markdown-exporter) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->atlassian-python-api->confluence-markdown-exporter) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->atlassian-python-api->confluence-markdown-exporter) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->atlassian-python-api->confluence-markdown-exporter) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->atlassian-python-api->confluence-markdown-exporter) (2025.4.26)
# Requirement already satisfied: click>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from typer->confluence-markdown-exporter) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from typer->confluence-markdown-exporter) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from typer->confluence-markdown-exporter) (14.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from rich>=10.11.0->typer->confluence-markdown-exporter) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/janishuser/Library/Python/3.12/lib/python/site-packages (from rich>=10.11.0->typer->confluence-markdown-exporter) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->confluence-markdown-exporter) (0.1.2)

# %%
# !confluence-markdown-exporter  config
# Out:
# e5h? Config file location: /Users/janishuser/Library/Application Support/confluenc
#
# Select a config to change (or reset): (Use arrow keys)
#  » Export Settings  [submenu]
#    Connection Configuration  [submenu]
#    Authentication  [submenu]
#    [Reset config to defaults]
#    [Exit]WARNING: your terminal doesn't support cursor position requests (CPR).
# e?25l? Config file location: /Users/janishuser/Library/Application Support/confluenc
#
# Select a config to change (or reset): (Use arrow keys)
#  » Export Settings  [submenu]
#    Connection Configuration  [submenu]
#    Authentication  [submenu]
#    [Reset config to defaults]
# eit]? Config file location: /Users/janishuser/Library/Application Support/confluenc
#  02m
# C ;5;102;1mSelect a config to change (or reset): (Use arrow keys)
#
# Cancelled by user

# %%
# !confluence-markdown-exporter pages https://janishuser.atlassian.net/wiki/spaces/~70121f63681e6d9614e7185f1d55159cde9f5/pages/294914/2025-12-08+Besprechungsnotizen
# Out:
# Confluence connection failed: Redirecting to Confluence authentication config...
# ? Edit options for 'Confluence Account': (Use arrow keys)
#  » Instance URL  Not set
#    Username (email)  Not set
#    API Token  Not set
#    Personal Access Token (PAT)  Not set
#    [Reset this group to defaults]
#    [Back]WARNING: your terminal doesn't support cursor position requests (CPR).
# ? Edit options for 'Confluence Account': (Use arrow keys)
#  » Instance URL  Not set
#    Username (email)  Not set
#    API Token  Not set
#    Personal Access Token (PAT)  Not set
#    [Reset this group to defaults]
# C  [Back]? Edit options for 'Confluence Account': (Use arrow keys)
#
# Cancelled by user
#
# Confluence connection failed: Redirecting to Confluence authentication config...
# s4h? Edit options for 'Confluence Account': Instance URL  https://janishuser.atlas
# s14;1mian.net/? Edit options for 'Confluence Account': Instance URL  https://janishuser.atlas
# ian.net/
# ? Instance URL
#
# Base URL of the Confluence or Jira instance.
#
# Change Instance URL to: https://janishuser.atlassian.net/
